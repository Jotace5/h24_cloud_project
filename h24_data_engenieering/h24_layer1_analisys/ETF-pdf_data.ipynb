# %% [markdown]
# ## Layer 1:
#
# ### 1- Segmentation Based on Service Provided
#
# - **Purpose**: Perform an initial classification based on the type of service provided, allowing for a first distinction between documents.
# - **Methodology**: In this first layer, files are categorized based on the service they represent, facilitating subsequent filtering stages.
#
# ### 2- Filtering by Number of Pages
#
# - **Purpose**: Refine the dataset by excluding documents that do not meet certain criteria defined by the data analyst.
# - **Methodology**: Files are distinguished based on their number of pages: 1-2, 3, 4-5, and 6 or more pages. This segmentation allows for a better understanding of the dataset composition and informed decisions on which documents to include for model training.
#
# ### 3- Identification through OCR and Classification
#
# - **Purpose**: Identify and categorize documents based on specific textual content, further optimizing data selection.
# - **Methodology**: An OCR process is implemented to detect the frequency of the word "Presentismo" in each file. This metric guides the decision of which documents should be prioritized or excluded in training.
#
# ### 4- Data Filtering
#
# - **Purpose**: Further refine the dataset according to specific criteria, ensuring optimal training.
# - **Methodology**: Using the detailed report of PDF file composition as reference, filtering is done based on visual characteristics and file size. The observed relationship between file size, image quality, and scanning medium guides the decision on which documents to exclude from training.
#
# ### 5- Compliance with GCP Requirements
#
# - **Purpose**: Ensure selected data meet the minimum standards established by GCP.
# - **Methodology**: Based on the report of PDF file composition per folder, segmentation and subsequent data filtering are performed. A limit of up to 1GB of data for training is set and documents are verified to meet the 8-point quality at 150 DPI requirement.
#
#    - **GCP Compliance**: It is essential to ensure that the final data meets GCP specifications.
#    - **Composition Report**: A detailed report reflecting the distribution and characteristics of PDF files in each folder is prepared.
#    - **Data Limits**: For training, up to a maximum of 1GB of data is selected, ensuring efficiency and optimal handling.
#    - **Quality Verification**: A check is conducted to ensure that documents contain text of at least 8 points at 150 DPI, in line with minimum requirements.
#
#    GCP Services - Custom model input requirements:
#
#       - **(OK)** For **PDF** and TIFF, **up to 1500 pages can be processed** (with a free tier subscription, only the first two pages are processed).
#
#       - **(OK)** The **file size** for analyzing documents must be less than **500 MB for paid (S0) tier** and 4 MB for free (F0) tier.
#
#       - **(OK)** **Image dimensions** must be between **50 x 50 pixels** and **10,000 px x 10,000 px.**
#
#       - **(OK)**  If your PDFs are password-locked, you must remove the lock before submission.
#
#       - **(OK)** The **minimum height of the text** to be extracted is **12 pixels for a 1024 x 768 pixel image**. This dimension corresponds to about **8-point text at 150 dots per inch (DPI).**
#
#       - **(OK)**  For **custom model training**, the maximum number of pages for training data is 500 for the custom template model and **50,000 for the custom neural model**.
#
#       - **(NO NEEDED)** For **custom extraction model training**, the total size of training data is 50 MB for template model and **1G-MB for the neural model**.
#
#       - **(OK)** For **custom classification model training**, the total size of training data is **1GB with a maximum of 10,000 pages**.
#
# ### Conclusion
#
# The detailed process provides a rigorous and structured method for PDF file preparation and filtering. This methodology ensures an optimized dataset, ready for training the HOUSE24 classification model, aligned with GCP standards.

# %% [markdown]
# NOTA: Realizar las modificaciones en las ubicaciones de los archivos y carpetas según corresponda.

# %% [markdown]
# ## 1- Segmentation Based on Service Provided

# %%
import PyPDF2
import shutil
import os

route = 'C:/Users/HP/My Drive/Artificial Intelligence/PROJECTS/House24 - Toto/House24 Invoicing/'
# Directory where the PDF files are located
pdf_directory = route + 'Psychology'

# Directory where PDFs with 1-2 pages will be saved
output_directory_1_2 = route + 'Psychology/PSI-1-2pags'

# Directory where PDFs with 3 pages will be saved
output_directory_3 = route + 'Psychology/PSI-3pags'

# Directory where PDFs with 4-5 pages will be saved
output_directory_4_5 = route + 'Psychology/PSI-4-5pags'

# Directory where PDFs with 6 or more pages will be saved
output_directory_6_plus = route + 'Psychology/PSI-6+pags'

# Create output directories if they don't exist
os.makedirs(output_directory_1_2, exist_ok=True)
os.makedirs(output_directory_3, exist_ok=True)
os.makedirs(output_directory_4_5, exist_ok=True)
os.makedirs(output_directory_6_plus, exist_ok=True)

# Iterate through files in the input directory
pdf_files = [filename for filename in os.listdir(pdf_directory) if filename.endswith('.pdf')]
total_files = len(pdf_files)
copied_files = 0

for filename in pdf_files:
    pdf_file_path = os.path.join(pdf_directory, filename)
    
    # Open the PDF file in binary read mode
    with open(pdf_file_path, 'rb') as pdf_file:
        pdf_reader = PyPDF2.PdfReader(pdf_file)
        num_pages = len(pdf_reader.pages)  # Get the number of pages
        
        # Decide which directory to place the PDF based on the number of pages
        if num_pages <= 2:
            output_path = os.path.join(output_directory_1_2, filename)
        elif num_pages == 3:
            output_path = os.path.join(output_directory_3, filename)
        elif 4 <= num_pages <= 5:
            output_path = os.path.join(output_directory_4_5, filename)
        elif num_pages >= 6:
            output_path = os.path.join(output_directory_6_plus, filename)
        
        # Copy the PDF file to the corresponding output directory
        shutil.copy(pdf_file_path, output_path)
        copied_files += 1
        
        # Calculate the progress percentage
        percentage = (copied_files / total_files) * 100
        
        print(f"{percentage:.2f}% completed, '{filename}' has been copied")

print("Process completed.")
# Out:
# 1.35% completado, Se ha copiado 'Evaluacion psicologica.pdf'
# 2.70% completado, Se ha copiado 'Psicologa (2).pdf'
# 4.05% completado, Se ha copiado 'Psicologa.pdf'
# 5.41% completado, Se ha copiado 'Psicologia (10).pdf'
# 6.76% completado, Se ha copiado 'Psicologia (11).pdf'
# 8.11% completado, Se ha copiado 'Psicologia (12).pdf'
# 9.46% completado, Se ha copiado 'Psicologia (2).pdf'
# 10.81% completado, Se ha copiado 'Psicologia (3).pdf'
# 12.16% completado, Se ha copiado 'Psicologia (4).pdf'
# 13.51% completado, Se ha copiado 'Psicologia (5).pdf'
# 14.86% completado, Se ha copiado 'Psicologia (6).pdf'
# 16.22% completado, Se ha copiado 'Psicologia (7).pdf'
# 17.57% completado, Se ha copiado 'Psicologia (8).pdf'
# 18.92% completado, Se ha copiado 'Psicologia (9).pdf'
# 20.27% completado, Se ha copiado 'Psicologia.pdf'
# 21.62% completado, Se ha copiado 'Psicología (10).pdf'
# 22.97% completado, Se ha copiado 'Psicología (11).pdf'
# 24.32% completado, Se ha copiado 'Psicología (12).pdf'
# 25.68% completado, Se ha copiado 'Psicología (13).pdf'
# 27.03% completado, Se ha copiado 'Psicología (14).pdf'
# 28.38% completado, Se ha copiado 'Psicología (15).pdf'
# 29.73% completado, Se ha copiado 'Psicología (16).pdf'
# 100.00% completado, Se ha copiado 'Psicología.pdf'
# Proceso completado.

# %% [markdown]
# ## 2- Filtering by Number of Pages

# %%
import os
import datetime

# Location directory
location = 'C:/Users/HP/My Drive/Artificial Intelligence/PROJECTS/House24 - Toto/House24 Invoicing'
report_version = '2.0'  # Change the version as needed

# Function to get the report of a folder
def get_folder_report(folder):
   
    full_folder_path = os.path.join(location, folder)
    
    # Counter for the total number of files in the folder
    total_files = 0
    
    # Iterate through files in the folder
    for _, _, files in os.walk(full_folder_path):
        total_files += len(files)
    
    # Get the current date
    current_date = datetime.date.today()
    report = f"Date: {current_date}\n"
    
    # Add the report version
    report += f"Version: {report_version}\n\n"
    
    report += f"Folder: {folder}\n"
    # Add the total number of files to the report
    report += f"Total PDFs: {total_files}\n"
    
    # Iterate through subfolders in the main folder
    for subfolder in os.listdir(full_folder_path):
        subfolder_full_path = os.path.join(full_folder_path, subfolder)
        if os.path.isdir(subfolder_full_path):
            # Calculate the number of files in the subfolder
            subfolder_files = len(os.listdir(subfolder_full_path))
            
            # Calculate the percentage of files relative to the total number of files
            percentage = (subfolder_files / total_files) * 100
            
            # Add the information to the report
            report += f"  -{subfolder}: {subfolder_files} PDFs - {percentage:.2f}%\n"
    
    return report

# Generate the report for all folders in the location
general_report = ""
for folder in os.listdir(location):
    if os.path.isdir(os.path.join(location, folder)):
        general_report += get_folder_report(folder)

# Write the report to a text file
file_name = f'report_v{report_version}.txt'
with open(file_name, 'w') as file:
    file.write(general_report)

print(f"Report generated successfully in '{file_name}'.")
# Out:
# Informe generado con éxito en 'informe_v3.0.txt'.

# %% [markdown]
# ## 3- Identification through OCR and Classification

# %%
import os
import pytesseract
from pdf2image import convert_from_path
import re
import nltk
from tqdm import tqdm

# Download the 'wordnet' resource from NLTK if you haven't downloaded it already
# nltk.download('wordnet')

# Function to find all word forms of the keyword
def find_all_word_forms(word):
    forms = set()
    # Add the original word and the variant "P R E S E N T I S M O" (without spaces)
    forms.add(word)
    forms.add("PRESENTISMO")
    # Find the lemma
    lemma = nltk.WordNetLemmatizer().lemmatize(word)
    # Add variations in lowercase and uppercase
    forms.add(word.lower())
    forms.add(word.upper())
    forms.add(word.capitalize())
    forms.add(lemma.lower())
    forms.add(lemma.upper())
    forms.add(lemma.capitalize())
    # Replace letters with accents and diacritics
    forms.add(re.sub(r'[^\x00-\x7F]+', '', word))
    forms.add(re.sub(r'[^\x00-\x7F]+', '', lemma))
    return list(forms)

# Base folder containing the 'CAREGIVER' folders
base_directory = 'C:/Users/HP/My Drive/Artificial Intelligence/PROJECTS/House24 - Toto/House24 Invoicing/Medical Visit'

# Get the list of folders in 'CAREGIVER'
caregiver_folders = [d for d in os.listdir(base_directory) if os.path.isdir(os.path.join(base_directory, d))]

# Keywords you want to search for (in this case, "Presentismo" and "P R E S E N T I S M O")
keywords = ["Presentismo", "P R E S E N T I S M O"]

# Counter for processed files
processed_counter = 0

# Iterate through the folders with a file-based progress bar
for caregiver_folder in caregiver_folders:
    pdf_directory = os.path.join(base_directory, caregiver_folder)

    # Get all word forms of the keyword
    word_forms = [form for keyword in keywords for form in find_all_word_forms(keyword)]

    # Initialize counters for this folder
    counters = {i: 0 for i in range(7)}  # Fixed to include counter 0
    files_with_presentismo = {i: [] for i in range(7)}

    # Iterate through the files in the current directory with tqdm
    for filename in tqdm(os.listdir(pdf_directory), desc=f"Progress ({caregiver_folder})", dynamic_ncols=True):
        if filename.endswith('.pdf'):
            pdf_file = os.path.join(pdf_directory, filename)

            # Extract images from the PDF
            images = convert_from_path(pdf_file)

            # Initialize a counter for this file
            counter = 0

            # Iterate through the images and search for the keywords
            for image in images:
                text = pytesseract.image_to_string(image)
                counter += sum(text.count(form) for form in word_forms)

            # Update the corresponding counter
            if counter >= 6:
                counters[6] += 1
                files_with_presentismo[6].append(filename)
            else:
                counters[counter] += 1
                files_with_presentismo[counter].append(filename)

            # Increment the processed file counter
            processed_counter += 1

            # Report file name for this folder
            report_name = f"presentismo_report_{caregiver_folder}.txt"

            # Open the report file in write mode
            with open(report_name, 'w', encoding='utf-8') as report:
                report.write(f"Report of files with the word 'Presentismo' in the folder '{caregiver_folder}':\n\n")
                for times, count in counters.items():
                    report.write(f"{times} times: {count} files\n")
                    report.write(f"Files with 'Presentismo' ({times} times):\n")
                    for file in files_with_presentismo[times]:
                        report.write(f"- {file}\n")
                    report.write("\n")

print("Analysis completed.")
# Out:
# Progreso (MED-1-2pags): 100%|██████████| 871/871 [1:08:39<00:00,  4.73s/it]
# Progreso (MED-3pags):  14%|█▎        | 53/390 [06:14<34:13,  6.09s/it]c:\Users\HP\anaconda3\Lib\site-packages\PIL\Image.py:3167: DecompressionBombWarning: Image size (123748730 pixels) exceeds limit of 89478485 pixels, could be decompression bomb DOS attack.
#   warnings.warn(
# Progreso (MED-3pags): 100%|██████████| 390/390 [50:38<00:00,  7.79s/it]
# Progreso (MED-4-5pags): 100%|██████████| 509/509 [1:35:12<00:00, 11.22s/it]
# Progreso (MED-6+pags): 100%|██████████| 322/322 [1:42:36<00:00, 19.12s/it]
# Análisis completo.

# %% [markdown]
# ## 4- Data Filtering

# %%
# Through the following script, you can extract the files that will not be used for training and save them in the selected destination folder.
import os
import shutil

# Base directory where the files will be searched
base_directory = 'C:/Users/HP/My Drive/Artificial Intelligence/PROJECTS/House24 - Toto/House24 Invoicing/Caregiver'

# Destination folder where the files will be moved
destination_folder = 'C:/Users/HP/My Drive/Artificial Intelligence/PROJECTS/House24 - Toto/House24 Invoicing/Concatenated Forms (Split)'

# List of file names you want to search for
file_names = [
    '''put list of files to search'''
]


# Iterate through the base directory and its subdirectories
for current_directory, subdirectories, files in os.walk(base_directory):
    for file_name in file_names:
        if file_name in files:
            # Full path of the found file
            source_path = os.path.join(current_directory, file_name)
            # Destination path where the file will be moved
            destination_path = os.path.join(destination_folder, file_name)

            # Move the file to the destination directory
            try:
                shutil.move(source_path, destination_path)
                print(f"{file_name} has been moved to {destination_path}")
            except Exception as e:
                print(f"Error moving {file_name}: {str(e)}")

print("Process completed.")
# Out:
# Proceso completado.

# %% [markdown]
# We organize and unify the files that will not be used for training into the folder.

# %%
import os
import shutil

# Path of the main folder
main_folder_path = 'C:/Users/HP/My Drive/Artificial Intelligence/PROJECTS/House24 - Toto/House24 Invoicing/Split'
destination_folder = 'C:/Users/HP/My Drive/Artificial Intelligence/PROJECTS/House24 - Toto/House24 Invoicing/Concatenated Forms (Split)'

# Function to move subfolders with files
def move_subfolders_with_files(path, destination):
    for current_directory, subdirectories, files in os.walk(path, topdown=False):
        for subdirectory in subdirectories:
            subfolder = os.path.join(current_directory, subdirectory)
            if os.listdir(subfolder):
                # If the subfolder is not empty, move it to the destination directory
                destination_subfolder = os.path.join(destination, subdirectory)
                shutil.move(subfolder, destination_subfolder)
                print(f"Subfolder with files moved to {destination_subfolder}: {subdirectory}")

# Call the function to move subfolders with files to the destination folder
move_subfolders_with_files(main_folder_path, destination_folder)
# Out:
# Subcarpeta con archivos movida a C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/Formularios concatenados (Dividir)\Kinesiologia Ej-22 (B).pdf: Kinesiologia Ej-22 (B).pdf
# Subcarpeta con archivos movida a C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/Formularios concatenados (Dividir)\Kinesiologia Ej-8.pdf: Kinesiologia Ej-8.pdf
# Subcarpeta con archivos movida a C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/Formularios concatenados (Dividir)\Kinesiologia Ej-9.pdf: Kinesiologia Ej-9.pdf
# Subcarpeta con archivos movida a C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/Formularios concatenados (Dividir)\Kinesiologia motora.pdf: Kinesiologia motora.pdf
# Subcarpeta con archivos movida a C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/Formularios concatenados (Dividir)\Kinesiología (10).pdf: Kinesiología (10).pdf
# Subcarpeta con archivos movida a C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/Formularios concatenados (Dividir)\Kinesiología (536).pdf: Kinesiología (536).pdf
# Subcarpeta con archivos movida a C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/Formularios concatenados (Dividir)\Kinesiología (625).pdf: Kinesiología (625).pdf
# Subcarpeta con archivos movida a C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/Formularios concatenados (Dividir)\Kinesiología 1 (6).pdf: Kinesiología 1 (6).pdf
# Subcarpeta con archivos movida a C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/Formularios concatenados (Dividir)\Kinesiología 1 (7).pdf: Kinesiología 1 (7).pdf
# Subcarpeta con archivos movida a C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/Formularios concatenados (Dividir)\Kinesiología 2 (2).pdf: Kinesiología 2 (2).pdf
# Subcarpeta con archivos movida a C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/Formularios concatenados (Dividir)\Kinesiología 2 (5).pdf: Kinesiología 2 (5).pdf
# Subcarpeta con archivos movida a C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/Formularios concatenados (Dividir)\Kinesiología 2 (6).pdf: Kinesiología 2 (6).pdf
# Subcarpeta con archivos movida a C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/Formularios concatenados (Dividir)\Kinesiología motora y respiratoria (65).pdf: Kinesiología motora y respiratoria (65).pdf
# Subcarpeta con archivos movida a C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/Formularios concatenados (Dividir)\M.M Pitelli Angela enf_03082022_130759.pdf: M.M Pitelli Angela enf_03082022_130759.pdf
# Subcarpeta con archivos movida a C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/Formularios concatenados (Dividir)\MARINA-Pitelli-cuidadora_09072022_201047.pdf: MARINA-Pitelli-cuidadora_09072022_201047.pdf
# Subcarpeta con archivos movida a C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/Formularios concatenados (Dividir)\MARINA-Pitelli-enfermeria_09072022_200948.pdf: MARINA-Pitelli-enfermeria_09072022_200948.pdf
# Subcarpeta con archivos movida a C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/Formularios concatenados (Dividir)\MM-PITELLI ANGELA-ENF_01062023_145852.pdf: MM-PITELLI ANGELA-ENF_01062023_145852.pdf
# Subcarpeta con archivos movida a C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/Formularios concatenados (Dividir)\OSDEPYM MOVIO MELINA FONO_09072022_171453.pdf: OSDEPYM MOVIO MELINA FONO_09072022_171453.pdf
# Subcarpeta con archivos movida a C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/Formularios concatenados (Dividir)\OSSEG EDITH VILLALBA ENF_09082022_151234.pdf: OSSEG EDITH VILLALBA ENF_09082022_151234.pdf
# Subcarpeta con archivos movida a C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/Formularios concatenados (Dividir)\OSSEG NIEVAS LILIA CUID_11072022_174837.pdf: OSSEG NIEVAS LILIA CUID_11072022_174837.pdf
# Subcarpeta con archivos movida a C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/Formularios concatenados (Dividir)\OSSEG VILLALBA EDITH ENF_11042022_151046.pdf: OSSEG VILLALBA EDITH ENF_11042022_151046.pdf
# Subcarpeta con archivos movida a C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/Formularios concatenados (Dividir)\osseg villalba enf_03042022_145425.pdf: osseg villalba enf_03042022_145425.pdf
# Subcarpeta con archivos movida a C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/Formularios concatenados (Dividir)\PFA -Velazquez Ester enfermeria.pdf: PFA -Velazquez Ester enfermeria.pdf
# Subcarpeta con archivos movida a C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/Formularios concatenados (Dividir)\PFA-PEREZ FLORENCIA-ENF_02082022_164932.pdf: PFA-PEREZ FLORENCIA-ENF_02082022_164932.pdf
# Subcarpeta con archivos movida a C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/Formularios concatenados (Dividir)\PFA-RONCAGLIA-CUID_10052022_172001.pdf: PFA-RONCAGLIA-CUID_10052022_172001.pdf
# Subcarpeta con archivos movida a C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/Formularios concatenados (Dividir)\PFA-VELAZQUEZ ESTER-CUID_10052022_164921.pdf: PFA-VELAZQUEZ ESTER-CUID_10052022_164921.pdf
# Subcarpeta con archivos movida a C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/Formularios concatenados (Dividir)\PFA-VELAZQUEZ ESTER-ENF_10052022_165118.pdf: PFA-VELAZQUEZ ESTER-ENF_10052022_165118.pdf
# Subcarpeta con archivos movida a C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/Formularios concatenados (Dividir)\PRENSA-Baez Daniela-enfer_07062022_190824.pdf: PRENSA-Baez Daniela-enfer_07062022_190824.pdf
# Subcarpeta con archivos movida a C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/Formularios concatenados (Dividir)\RELOJ-Cabrera-Enf_07072022_131956.pdf: RELOJ-Cabrera-Enf_07072022_131956.pdf
# Subcarpeta con archivos movida a C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/Formularios concatenados (Dividir)\RELOJ-GIOFFRE MONICA-ENF_02082022_173623.pdf: RELOJ-GIOFFRE MONICA-ENF_02082022_173623.pdf
# Subcarpeta con archivos movida a C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/Formularios concatenados (Dividir)\RELOJ-RODRIGUEZ OSVALDO-ENF_06072022_125747.pdf: RELOJ-RODRIGUEZ OSVALDO-ENF_06072022_125747.pdf
# Subcarpeta con archivos movida a C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/Formularios concatenados (Dividir)\Seguros-Villalba Edith-Enfermeria_06082022_092547.pdf: Seguros-Villalba Edith-Enfermeria_06082022_092547.pdf
# Subcarpeta con archivos movida a C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/Formularios concatenados (Dividir)\TORRES PATRICIA CUID_09082022_141201.pdf: TORRES PATRICIA CUID_09082022_141201.pdf

# %% [markdown]
# We modify the names of the files for better control and organization of the dataset.

# %%
import os

# Path of the main folder where the files and subfolders are located
main_folder_path = 'C:/Users/HP/My Drive/Artificial Intelligence/PROJECTS/House24 - Toto/House24 Invoicing/'
main_folder = main_folder_path + 'Medical Visit'

# Check if the main folder exists
if os.path.exists(main_folder):
    # Initialize a global counter for all Cardiologist files
    cardiologist_counter = 0

    # Iterate through the main folder and all its subfolders
    for current_directory, subdirectories, files in os.walk(main_folder):
        for file in files:
            if file.lower().endswith('.pdf'):
                cardiologist_counter += 1
                new_name = f'Form{cardiologist_counter}- MED.pdf'
                
                # Full path of source and destination
                source = os.path.join(current_directory, file)
                destination = os.path.join(current_directory, new_name)

                # Rename the file
                os.rename(source, destination)
                print(f"Renamed: {file} -> {new_name}")
else:
    print(f"The main folder {main_folder} does not exist.")
# Out:
# Renombrado: Achilli Maria Luisa (Medico).pdf -> Form1- MED.pdf
# Renombrado: AGOSTO - OSOSS - ABAD, Jose (Medico).pdf -> Form2- MED.pdf
# Renombrado: ALBA AURORA (MEDICO).pdf -> Form3- MED.pdf
# Renombrado: AMIGO NELIDA (05-05 Médico).pdf -> Form4- MED.pdf
# Renombrado: BARONI TERESA (MEDICO).pdf -> Form5- MED.pdf
# Renombrado: Barrera Raquel (Medico) (2).pdf -> Form6- MED.pdf
# Renombrado: Barrera Raquel (Medico) (3).pdf -> Form7- MED.pdf
# Renombrado: Barrera Raquel (Medico) (4).pdf -> Form8- MED.pdf
# Renombrado: Barrera Raquel (Medico) (5).pdf -> Form9- MED.pdf
# Renombrado: Barrera Raquel (Médico) (2).pdf -> Form10- MED.pdf
# Renombrado: Barrera Raquel (Médico) (3).pdf -> Form11- MED.pdf
# Renombrado: Barrera Raquel (Médico).pdf -> Form12- MED.pdf
# Renombrado: BRUNET NORMA (MEDICO).pdf -> Form13- MED.pdf
# Renombrado: CAIBOZN SALOMON (16-05 Médico).pdf -> Form14- MED.pdf
# Renombrado: CALORI OSVALDO (06-05 Médico).pdf -> Form15- MED.pdf
# Renombrado: Capirone Angela (MEDICO).pdf -> Form16- MED.pdf
# Renombrado: CASAS OSVALDO (MEDICO).pdf -> Form17- MED.pdf
# Renombrado: MACCHIAVELLO CARMEN (MEDICO) (2).pdf -> Form53- MED.pdf
# Renombrado: MACCHIAVELLO CARMEN (MEDICO).pdf -> Form54- MED.pdf
# Renombrado: Marcus de Reynoso Olga (MEDICO).pdf -> Form55- MED.pdf
# Renombrado: MAUCERI JOSE (07-05 Médico).pdf -> Form56- MED.pdf
# Renombrado: MEDICO (ALVAREZ 21-2.pdf -> Form57- MED.pdf
# Renombrado: MEDICO (ALVAREZ) 8-2.pdf -> Form58- MED.pdf
# Renombrado: MEDICO (BUSTOS) (100).pdf -> Form59- MED.pdf
# Renombrado: MEDICO (BUSTOS) (101).pdf -> Form60- MED.pdf
# Renombrado: MEDICO (BUSTOS) (102).pdf -> Form61- MED.pdf
# Renombrado: MEDICO (BUSTOS) (103).pdf -> Form62- MED.pdf
# Renombrado: MEDICO (BUSTOS) (104).pdf -> Form63- MED.pdf
# Renombrado: MEDICO (BUSTOS) (105).pdf -> Form64- MED.pdf
# Renombrado: MEDICO (BUSTOS) (107).pdf -> Form65- MED.pdf
# Renombrado: MEDICO (BUSTOS) (108).pdf -> Form66- MED.pdf
# Renombrado: MEDICO (BUSTOS) (110).pdf -> Form67- MED.pdf
# Renombrado: MEDICO (BUSTOS) (112).pdf -> Form68- MED.pdf
# Renombrado: MEDICO (BUSTOS) (113).pdf -> Form69- MED.pdf
# Renombrado: MEDICO (BUSTOS) (114).pdf -> Form70- MED.pdf
# Renombrado: MEDICO (BUSTOS) (115).pdf -> Form71- MED.pdf
# Renombrado: MEDICO (BUSTOS) (116).pdf -> Form72- MED.pdf
# Renombrado: MEDICO (BUSTOS) (117).pdf -> Form73- MED.pdf
# Renombrado: MEDICO (BUSTOS) (118).pdf -> Form74- MED.pdf
# Renombrado: MEDICO (BUSTOS) (121).pdf -> Form75- MED.pdf
# Renombrado: MEDICO (BUSTOS) (124).pdf -> Form76- MED.pdf
# Renombrado: MEDICO (BUSTOS) (125).pdf -> Form77- MED.pdf
# Renombrado: MEDICO (BUSTOS) (126).pdf -> Form78- MED.pdf
# Renombrado: MEDICO (BUSTOS) (127).pdf -> Form79- MED.pdf
# Renombrado: MEDICO (BUSTOS) (128).pdf -> Form80- MED.pdf
# Renombrado: MEDICO (BUSTOS) (129).pdf -> Form81- MED.pdf
# Renombrado: MEDICO (BUSTOS) (138).pdf -> Form82- MED.pdf
# Renombrado: MEDICO (BUSTOS) (139).pdf -> Form83- MED.pdf
# Renombrado: MEDICO (BUSTOS) (146).pdf -> Form84- MED.pdf
# Renombrado: MEDICO (BUSTOS) (147).pdf -> Form85- MED.pdf
# Renombrado: MEDICO (BUSTOS) (148).pdf -> Form86- MED.pdf
# Renombrado: MEDICO (BUSTOS) (149).pdf -> Form87- MED.pdf
# Renombrado: MEDICO (BUSTOS) (150).pdf -> Form88- MED.pdf
# Renombrado: MEDICO (BUSTOS) (151).pdf -> Form89- MED.pdf
# Renombrado: MEDICO (BUSTOS) (152).pdf -> Form90- MED.pdf
# Renombrado: MEDICO (BUSTOS) (155).pdf -> Form91- MED.pdf
# Renombrado: MEDICO (BUSTOS) (160).pdf -> Form92- MED.pdf
# Renombrado: MEDICO (BUSTOS) (161).pdf -> Form93- MED.pdf
# Renombrado: MEDICO (BUSTOS) (162).pdf -> Form94- MED.pdf
# Renombrado: MEDICO (BUSTOS) (164).pdf -> Form95- MED.pdf
# Renombrado: MEDICO (BUSTOS) (165).pdf -> Form96- MED.pdf
# Renombrado: MEDICO (BUSTOS) (166).pdf -> Form97- MED.pdf
# Renombrado: MEDICO (BUSTOS) (167).pdf -> Form98- MED.pdf
# Renombrado: MEDICO (BUSTOS) (168).pdf -> Form99- MED.pdf
# Renombrado: MEDICO (BUSTOS) (169).pdf -> Form100- MED.pdf
# Renombrado: MEDICO (BUSTOS) (170).pdf -> Form101- MED.pdf
# Renombrado: MEDICO (BUSTOS) (171).pdf -> Form102- MED.pdf
# Renombrado: MEDICO (BUSTOS) (172).pdf -> Form103- MED.pdf
# Renombrado: MEDICO (BUSTOS) (175).pdf -> Form104- MED.pdf
# Renombrado: MEDICO (BUSTOS) (176).pdf -> Form105- MED.pdf
# Renombrado: MEDICO (BUSTOS) (178).pdf -> Form106- MED.pdf
# Renombrado: MEDICO (BUSTOS) (179).pdf -> Form107- MED.pdf
# Renombrado: MEDICO (BUSTOS) (180).pdf -> Form108- MED.pdf
# Renombrado: MEDICO (BUSTOS) (181).pdf -> Form109- MED.pdf
# Renombrado: MEDICO (BUSTOS) (182).pdf -> Form110- MED.pdf
# Renombrado: MEDICO (BUSTOS) (184).pdf -> Form111- MED.pdf
# Renombrado: MEDICO (BUSTOS) (185).pdf -> Form112- MED.pdf
# Renombrado: MEDICO (BUSTOS) (186).pdf -> Form113- MED.pdf
# Renombrado: MEDICO (BUSTOS) (187).pdf -> Form114- MED.pdf
# Renombrado: MEDICO (BUSTOS) (188).pdf -> Form115- MED.pdf
# Renombrado: MEDICO (BUSTOS) (189).pdf -> Form116- MED.pdf
# Renombrado: MEDICO (BUSTOS) (190).pdf -> Form117- MED.pdf
# Renombrado: MEDICO (BUSTOS) (195).pdf -> Form118- MED.pdf
# Renombrado: MEDICO (BUSTOS) (196).pdf -> Form119- MED.pdf
# Renombrado: MEDICO (BUSTOS) (198).pdf -> Form120- MED.pdf
# Renombrado: MEDICO (BUSTOS) (199).pdf -> Form121- MED.pdf
# Renombrado: MEDICO (BUSTOS) (200).pdf -> Form122- MED.pdf
# Renombrado: MEDICO (BUSTOS) (201).pdf -> Form123- MED.pdf
# Renombrado: MEDICO (BUSTOS) (202).pdf -> Form124- MED.pdf
# Renombrado: MEDICO (BUSTOS) (204).pdf -> Form125- MED.pdf
# Renombrado: MEDICO (BUSTOS) (206).pdf -> Form126- MED.pdf
# Renombrado: MEDICO (BUSTOS) (207).pdf -> Form127- MED.pdf
# Renombrado: MEDICO (BUSTOS) (208).pdf -> Form128- MED.pdf
# Renombrado: MEDICO (BUSTOS) (209).pdf -> Form129- MED.pdf
# Renombrado: MEDICO (BUSTOS) (210).pdf -> Form130- MED.pdf
# Renombrado: MEDICO (BUSTOS) (212).pdf -> Form131- MED.pdf
# Renombrado: MEDICO (BUSTOS) (213).pdf -> Form132- MED.pdf
# Renombrado: MEDICO (BUSTOS) (214).pdf -> Form133- MED.pdf
# Renombrado: MEDICO (BUSTOS) (215).pdf -> Form134- MED.pdf
# Renombrado: MEDICO (BUSTOS) (216).pdf -> Form135- MED.pdf
# Renombrado: MEDICO (BUSTOS) (217).pdf -> Form136- MED.pdf
# Renombrado: MEDICO (BUSTOS) (218).pdf -> Form137- MED.pdf
# Renombrado: MEDICO (BUSTOS) (219).pdf -> Form138- MED.pdf
# Renombrado: MEDICO (BUSTOS) (220).pdf -> Form139- MED.pdf
# Renombrado: MEDICO (BUSTOS) (221).pdf -> Form140- MED.pdf
# Renombrado: MEDICO (BUSTOS) (223).pdf -> Form141- MED.pdf
# Renombrado: MEDICO (BUSTOS) (224).pdf -> Form142- MED.pdf
# Renombrado: MEDICO (BUSTOS) (225).pdf -> Form143- MED.pdf
# Renombrado: MEDICO (BUSTOS) (226).pdf -> Form144- MED.pdf
# Renombrado: MEDICO (BUSTOS) (227).pdf -> Form145- MED.pdf
# Renombrado: MEDICO (BUSTOS) (228).pdf -> Form146- MED.pdf
# Renombrado: MEDICO (BUSTOS) (229).pdf -> Form147- MED.pdf
# Renombrado: MEDICO (BUSTOS) (231).pdf -> Form148- MED.pdf
# Renombrado: MEDICO (BUSTOS) (235).pdf -> Form149- MED.pdf
# Renombrado: MEDICO (BUSTOS) (236).pdf -> Form150- MED.pdf
# Renombrado: MEDICO (BUSTOS) (248).pdf -> Form151- MED.pdf
# Renombrado: MEDICO (BUSTOS) (249).pdf -> Form152- MED.pdf
# Renombrado: MEDICO (BUSTOS) (250).pdf -> Form153- MED.pdf
# Renombrado: MEDICO (BUSTOS) (251).pdf -> Form154- MED.pdf
# Renombrado: MEDICO (BUSTOS) (252).pdf -> Form155- MED.pdf
# Renombrado: MEDICO (BUSTOS) (253).pdf -> Form156- MED.pdf
# Renombrado: MEDICO (BUSTOS) (254).pdf -> Form157- MED.pdf
# Renombrado: MEDICO (BUSTOS) (255).pdf -> Form158- MED.pdf
# Renombrado: MEDICO (BUSTOS) (256).pdf -> Form159- MED.pdf
# Renombrado: MEDICO (BUSTOS) (257).pdf -> Form160- MED.pdf
# Renombrado: MEDICO (BUSTOS) (258).pdf -> Form161- MED.pdf
# Renombrado: MEDICO (BUSTOS) (259).pdf -> Form162- MED.pdf
# Renombrado: MEDICO (BUSTOS) (260).pdf -> Form163- MED.pdf
# Renombrado: MEDICO (BUSTOS) (261).pdf -> Form164- MED.pdf
# Renombrado: MEDICO (BUSTOS) (262).pdf -> Form165- MED.pdf
# Renombrado: MEDICO (BUSTOS) (263).pdf -> Form166- MED.pdf
# Renombrado: MEDICO (BUSTOS) (264).pdf -> Form167- MED.pdf
# Renombrado: MEDICO (BUSTOS) (277).pdf -> Form168- MED.pdf
# Renombrado: MEDICO (BUSTOS) (278).pdf -> Form169- MED.pdf
# Renombrado: MEDICO (BUSTOS) (279).pdf -> Form170- MED.pdf
# Renombrado: MEDICO (BUSTOS) (280).pdf -> Form171- MED.pdf
# Renombrado: MEDICO (BUSTOS) (281).pdf -> Form172- MED.pdf
# Renombrado: MEDICO (BUSTOS) (282).pdf -> Form173- MED.pdf
# Renombrado: MEDICO (BUSTOS) (283).pdf -> Form174- MED.pdf
# Renombrado: MEDICO (BUSTOS) (284).pdf -> Form175- MED.pdf
# Renombrado: MEDICO (BUSTOS) (57).pdf -> Form176- MED.pdf
# Renombrado: MEDICO (BUSTOS) (62).pdf -> Form177- MED.pdf
# Renombrado: MEDICO (BUSTOS) (81).pdf -> Form178- MED.pdf
# Renombrado: MEDICO (BUSTOS) (83).pdf -> Form179- MED.pdf
# Renombrado: MEDICO (BUSTOS) (84).pdf -> Form180- MED.pdf
# Renombrado: MEDICO (BUSTOS) (85).pdf -> Form181- MED.pdf
# Renombrado: MEDICO (BUSTOS) (86).pdf -> Form182- MED.pdf
# Renombrado: MEDICO (BUSTOS) (89).pdf -> Form183- MED.pdf
# Renombrado: MEDICO (BUSTOS) (92).pdf -> Form184- MED.pdf
# Renombrado: MEDICO (BUSTOS) (93).pdf -> Form185- MED.pdf
# Renombrado: MEDICO (BUSTOS) (95).pdf -> Form186- MED.pdf
# Renombrado: MEDICO (BUSTOS) (96).pdf -> Form187- MED.pdf
# Renombrado: MEDICO (BUSTOS) (97).pdf -> Form188- MED.pdf
# Renombrado: MEDICO (BUSTOS) (98).pdf -> Form189- MED.pdf
# Renombrado: MEDICO (BUSTOS) (99).pdf -> Form190- MED.pdf
# Renombrado: MEDICO (CAPURRO) (1).pdf -> Form191- MED.pdf
# Renombrado: MEDICO (CAPURRO) (10).pdf -> Form192- MED.pdf
# Renombrado: MEDICO (CAPURRO) (11).pdf -> Form193- MED.pdf
# Renombrado: MEDICO (CAPURRO) (12).pdf -> Form194- MED.pdf
# Renombrado: MEDICO (CAPURRO) (13).pdf -> Form195- MED.pdf
# Renombrado: MEDICO (CAPURRO) (14).pdf -> Form196- MED.pdf
# Renombrado: MEDICO (CAPURRO) (15).pdf -> Form197- MED.pdf
# Renombrado: MEDICO (CAPURRO) (16).pdf -> Form198- MED.pdf
# Renombrado: MEDICO (CAPURRO) (17).pdf -> Form199- MED.pdf
# Renombrado: MEDICO (CAPURRO) (18).pdf -> Form200- MED.pdf
# Renombrado: MEDICO (CAPURRO) (19).pdf -> Form201- MED.pdf
# Renombrado: MEDICO (CAPURRO) (2).pdf -> Form202- MED.pdf
# Renombrado: MEDICO (CAPURRO) (20).pdf -> Form203- MED.pdf
# Renombrado: MEDICO (CAPURRO) (21).pdf -> Form204- MED.pdf
# Renombrado: MEDICO (CAPURRO) (22).pdf -> Form205- MED.pdf
# Renombrado: MEDICO (CAPURRO) (23).pdf -> Form206- MED.pdf
# Renombrado: MEDICO (CAPURRO) (24).pdf -> Form207- MED.pdf
# Renombrado: MEDICO (MORALES) (20).pdf -> Form496- MED.pdf
# Renombrado: MEDICO (MORALES) (21).pdf -> Form497- MED.pdf
# Renombrado: MEDICO (MORALES) (22).pdf -> Form498- MED.pdf
# Renombrado: MEDICO (MORALES) (25).pdf -> Form499- MED.pdf
# Renombrado: MEDICO (MORALES) (28).pdf -> Form500- MED.pdf
# Renombrado: MEDICO (MORALES) (29).pdf -> Form501- MED.pdf
# Renombrado: MEDICO (MORALES) (31).pdf -> Form502- MED.pdf
# Renombrado: MEDICO (MORALES) (32).pdf -> Form503- MED.pdf
# Renombrado: MEDICO (MORALES) (34).pdf -> Form504- MED.pdf
# Renombrado: MEDICO (MORALES) (35).pdf -> Form505- MED.pdf
# Renombrado: MEDICO (MORALES) (36).pdf -> Form506- MED.pdf
# Renombrado: MEDICO (MORALES) (39).pdf -> Form507- MED.pdf
# Renombrado: MEDICO (MORALES) (41).pdf -> Form508- MED.pdf
# Renombrado: MEDICO (MORALES) (42).pdf -> Form509- MED.pdf
# Renombrado: MEDICO (MORALES) (43).pdf -> Form510- MED.pdf
# Renombrado: MEDICO (MORALES) (45).pdf -> Form511- MED.pdf
# Renombrado: MEDICO (MORALES) (47).pdf -> Form512- MED.pdf
# Renombrado: MEDICO (MORALES) (49).pdf -> Form513- MED.pdf
# Renombrado: MEDICO (MORALES) (50).pdf -> Form514- MED.pdf
# Renombrado: MEDICO (MORALES) (51).pdf -> Form515- MED.pdf
# Renombrado: MEDICO (MORALES) (52).pdf -> Form516- MED.pdf
# Renombrado: MEDICO (MORALES) (53).pdf -> Form517- MED.pdf
# Renombrado: MEDICO (MORALES) (54).pdf -> Form518- MED.pdf
# Renombrado: MEDICO (MORALES) (55).pdf -> Form519- MED.pdf
# Renombrado: MEDICO (MORALES) (56).pdf -> Form520- MED.pdf
# Renombrado: MEDICO (MORALES) (57).pdf -> Form521- MED.pdf
# Renombrado: MEDICO (MORALES) (6).pdf -> Form522- MED.pdf
# Renombrado: MEDICO (MORALES) (9).pdf -> Form523- MED.pdf
# Renombrado: MEDICO (MORALES) 3-6 (2).pdf -> Form524- MED.pdf
# Renombrado: MEDICO (MORALES) 3-6 (3).pdf -> Form525- MED.pdf
# Renombrado: MEDICO (MORALES) 3-6.pdf -> Form526- MED.pdf
# Renombrado: MEDICO (ORDAZ) (1).pdf -> Form527- MED.pdf
# Renombrado: MEDICO (ORDAZ) (100).pdf -> Form528- MED.pdf
# Renombrado: MEDICO (ORDAZ) (110).pdf -> Form529- MED.pdf
# Renombrado: MEDICO (ORDAZ) (112).pdf -> Form530- MED.pdf
# Renombrado: MEDICO (ORDAZ) (114).pdf -> Form531- MED.pdf
# Renombrado: MEDICO (ORDAZ) (116).pdf -> Form532- MED.pdf
# Renombrado: MEDICO (ORDAZ) (117).pdf -> Form533- MED.pdf
# Renombrado: MEDICO (ORDAZ) (119).pdf -> Form534- MED.pdf
# Renombrado: MEDICO (ORDAZ) (121).pdf -> Form535- MED.pdf
# Renombrado: MEDICO (ORDAZ) (124).pdf -> Form536- MED.pdf
# Renombrado: MEDICO (ORDAZ) (126).pdf -> Form537- MED.pdf
# Renombrado: MEDICO (ORDAZ) (128).pdf -> Form538- MED.pdf
# Renombrado: MEDICO (ORDAZ) (129).pdf -> Form539- MED.pdf
# Renombrado: MEDICO (ORDAZ) (13).pdf -> Form540- MED.pdf
# Renombrado: MEDICO (ORDAZ) (130).pdf -> Form541- MED.pdf
# Renombrado: MEDICO (ORDAZ) (131).pdf -> Form542- MED.pdf
# Renombrado: MEDICO (ORDAZ) (132).pdf -> Form543- MED.pdf
# Renombrado: MEDICO (ORDAZ) (134).pdf -> Form544- MED.pdf
# Renombrado: MEDICO (ORDAZ) (135).pdf -> Form545- MED.pdf
# Renombrado: MEDICO (ORDAZ) (136).pdf -> Form546- MED.pdf
# Renombrado: MEDICO (ORDAZ) (137).pdf -> Form547- MED.pdf
# Renombrado: MEDICO (ORDAZ) (138).pdf -> Form548- MED.pdf
# Renombrado: MEDICO (ORDAZ) (142).pdf -> Form549- MED.pdf
# Renombrado: MEDICO (ORDAZ) (143).pdf -> Form550- MED.pdf
# Renombrado: MEDICO (ORDAZ) (15).pdf -> Form551- MED.pdf
# Renombrado: MEDICO (ORDAZ) (16).pdf -> Form552- MED.pdf
# Renombrado: MEDICO (ORDAZ) (17).pdf -> Form553- MED.pdf
# Renombrado: MEDICO (ORDAZ) (20).pdf -> Form554- MED.pdf
# Renombrado: MEDICO (ORDAZ) (27).pdf -> Form555- MED.pdf
# Renombrado: MEDICO (ORDAZ) (28).pdf -> Form556- MED.pdf
# Renombrado: MEDICO (ORDAZ) (38).pdf -> Form557- MED.pdf
# Renombrado: MEDICO (ORDAZ) (39).pdf -> Form558- MED.pdf
# Renombrado: MEDICO (ORDAZ) (4).pdf -> Form559- MED.pdf
# Renombrado: MEDICO (ORDAZ) (41).pdf -> Form560- MED.pdf
# Renombrado: MEDICO (ORDAZ) (47).pdf -> Form561- MED.pdf
# Renombrado: MEDICO (ORDAZ) (49).pdf -> Form562- MED.pdf
# Renombrado: MEDICO (ORDAZ) (52).pdf -> Form563- MED.pdf
# Renombrado: MEDICO (ORDAZ) (54).pdf -> Form564- MED.pdf
# Renombrado: MEDICO (ORDAZ) (55).pdf -> Form565- MED.pdf
# Renombrado: MEDICO (ORDAZ) (56).pdf -> Form566- MED.pdf
# Renombrado: MEDICO (ORDAZ) (57).pdf -> Form567- MED.pdf
# Renombrado: MEDICO (ORDAZ) (60).pdf -> Form568- MED.pdf
# Renombrado: MEDICO (ORDAZ) (61).pdf -> Form569- MED.pdf
# Renombrado: MEDICO (ORDAZ) (63).pdf -> Form570- MED.pdf
# Renombrado: MEDICO (ORDAZ) (64).pdf -> Form571- MED.pdf
# Renombrado: MEDICO (ORDAZ) (66).pdf -> Form572- MED.pdf
# Renombrado: MEDICO (ORDAZ) (67).pdf -> Form573- MED.pdf
# Renombrado: MEDICO (ORDAZ) (68).pdf -> Form574- MED.pdf
# Renombrado: MEDICO (ORDAZ) (69).pdf -> Form575- MED.pdf
# Renombrado: MEDICO (ORDAZ) (7).pdf -> Form576- MED.pdf
# Renombrado: MEDICO (ORDAZ) (70).pdf -> Form577- MED.pdf
# Renombrado: MEDICO (ORDAZ) (71).pdf -> Form578- MED.pdf
# Renombrado: MEDICO (ORDAZ) (72).pdf -> Form579- MED.pdf
# Renombrado: MEDICO (ORDAZ) (73).pdf -> Form580- MED.pdf
# Renombrado: MEDICO (ORDAZ) (74).pdf -> Form581- MED.pdf
# Renombrado: MEDICO (ORDAZ) (75).pdf -> Form582- MED.pdf
# Renombrado: MEDICO (ORDAZ) (76).pdf -> Form583- MED.pdf
# Renombrado: MEDICO (ORDAZ) (77).pdf -> Form584- MED.pdf
# Renombrado: MEDICO (ORDAZ) (78).pdf -> Form585- MED.pdf
# Renombrado: MEDICO (ORDAZ) (79).pdf -> Form586- MED.pdf
# Renombrado: MEDICO (ORDAZ) (80).pdf -> Form587- MED.pdf
# Renombrado: MEDICO (ORDAZ) (81).pdf -> Form588- MED.pdf
# Renombrado: MEDICO (ORDAZ) (82).pdf -> Form589- MED.pdf
# Renombrado: MEDICO (ORDAZ) (83).pdf -> Form590- MED.pdf
# Renombrado: MEDICO (ORDAZ) (86).pdf -> Form591- MED.pdf
# Renombrado: MEDICO (ORDAZ) (90).pdf -> Form592- MED.pdf
# Renombrado: MEDICO (PRATTO) (2).pdf -> Form593- MED.pdf
# Renombrado: MEDICO (PRATTO) (3).pdf -> Form594- MED.pdf
# Renombrado: MEDICO (PRATTO) (4).pdf -> Form595- MED.pdf
# Renombrado: MEDICO (PRATTO) (5).pdf -> Form596- MED.pdf
# Renombrado: MEDICO (PRATTO) (6).pdf -> Form597- MED.pdf
# Renombrado: MEDICO (PRATTO) (7).pdf -> Form598- MED.pdf
# Renombrado: MEDICO (PRATTO).pdf -> Form599- MED.pdf
# Renombrado: MEDICO (RAIDELIS) (10).pdf -> Form600- MED.pdf
# Renombrado: MEDICO (RAIDELIS) (11).pdf -> Form601- MED.pdf
# Renombrado: MEDICO (RAIDELIS) (12).pdf -> Form602- MED.pdf
# Renombrado: MEDICO (RAIDELIS) (13).pdf -> Form603- MED.pdf
# Renombrado: MEDICO (RAIDELIS) (14).pdf -> Form604- MED.pdf
# Renombrado: MEDICO (RAIDELIS) (15).pdf -> Form605- MED.pdf
# Renombrado: MEDICO (RAIDELIS) (16).pdf -> Form606- MED.pdf
# Renombrado: MEDICO (RAIDELIS) (17).pdf -> Form607- MED.pdf
# Renombrado: MEDICO (RAIDELIS) (18).pdf -> Form608- MED.pdf
# Renombrado: MEDICO (RAIDELIS) (19).pdf -> Form609- MED.pdf
# Renombrado: MEDICO (RAIDELIS) (2).pdf -> Form610- MED.pdf
# Renombrado: MEDICO (RAIDELIS) (20).pdf -> Form611- MED.pdf
# Renombrado: MEDICO (RAIDELIS) (21).pdf -> Form612- MED.pdf
# Renombrado: MEDICO (RAIDELIS) (22).pdf -> Form613- MED.pdf
# Renombrado: MEDICO (RAIDELIS) (23).pdf -> Form614- MED.pdf
# Renombrado: MEDICO (RAIDELIS) (24).pdf -> Form615- MED.pdf
# Renombrado: MEDICO (RAIDELIS) (25).pdf -> Form616- MED.pdf
# Renombrado: MEDICO (RAIDELIS) (26).pdf -> Form617- MED.pdf
# Renombrado: MEDICO (RAIDELIS) (27).pdf -> Form618- MED.pdf
# Renombrado: MEDICO (RAIDELIS) (28).pdf -> Form619- MED.pdf
# Renombrado: MEDICO (RAIDELIS) (29).pdf -> Form620- MED.pdf
# Renombrado: MEDICO (RAIDELIS) (3).pdf -> Form621- MED.pdf
# Renombrado: MEDICO (RAIDELIS) (30).pdf -> Form622- MED.pdf
# Renombrado: MEDICO (RAIDELIS) (31).pdf -> Form623- MED.pdf
# Renombrado: MEDICO (RAIDELIS) (32).pdf -> Form624- MED.pdf
# Renombrado: MEDICO (RAIDELIS) (33).pdf -> Form625- MED.pdf
# Renombrado: MEDICO (RAIDELIS) (34).pdf -> Form626- MED.pdf
# Renombrado: MEDICO (RAIDELIS) (35).pdf -> Form627- MED.pdf
# Renombrado: MEDICO (RAIDELIS) (4).pdf -> Form628- MED.pdf
# Renombrado: MEDICO (RAIDELIS) (5).pdf -> Form629- MED.pdf
# Renombrado: MEDICO (RAIDELIS) (6).pdf -> Form630- MED.pdf
# Renombrado: MEDICO (RAIDELIS) (7).pdf -> Form631- MED.pdf
# Renombrado: MEDICO (RAIDELIS)
# Renombrado: MICHALEC VLADISLABA (MEDICO).pdf -> Form698- MED.pdf
# Renombrado: MORENO NOEMI (8 Médico).pdf -> Form699- MED.pdf
# Renombrado: Moreno Noemi (Medico) (2).pdf -> Form700- MED.pdf
# Renombrado: Moreno Noemi (Medico) (3).pdf -> Form701- MED.pdf
# Renombrado: Moreno Noemi (Medico).pdf -> Form702- MED.pdf
# Renombrado: Moreno Noemi (Médico).pdf -> Form703- MED.pdf
# Renombrado: MURUA MARIA (06-05 Médico).pdf -> Form704- MED.pdf
# Renombrado: Novarezco Beatriz (Medico).pdf -> Form705- MED.pdf
# Renombrado: ORTIZ OMAR (25 Médico Médico).pdf -> Form706- MED.pdf
# Renombrado: Ortiz Omar (Medico) (2).pdf -> Form707- MED.pdf
# Renombrado: Ortiz Omar (Medico) (3).pdf -> Form708- MED.pdf
# Renombrado: Ortiz Omar (Medico) (4).pdf -> Form709- MED.pdf
# Renombrado: Ortiz Omar (Medico) (5).pdf -> Form710- MED.pdf
# Renombrado: ORTIZ OMAR (MEDICO).pdf -> Form711- MED.pdf
# Renombrado: Ortiz Omar (Médico) (2).pdf -> Form712- MED.pdf
# Renombrado: Ortiz Omar (Médico).pdf -> Form713- MED.pdf
# Renombrado: PAIVA OSCAR (MEDICO).pdf -> Form714- MED.pdf
# Renombrado: PAZ PINTO (04-05 Médico).pdf -> Form715- MED.pdf
# Renombrado: Penalba Hebe (MEDICO - DE SETA).pdf -> Form716- MED.pdf
# Renombrado: PEREIRA LUIS (04-05 Médico).pdf -> Form717- MED.pdf
# Renombrado: Perez Jorge (Medico) (2).pdf -> Form718- MED.pdf
# Renombrado: Perez Jorge (Medico) (3).pdf -> Form719- MED.pdf
# Renombrado: Perez Jorge (Medico).pdf -> Form720- MED.pdf
# Renombrado: PIÑON CELIA (06-05 Médico).pdf -> Form721- MED.pdf
# Renombrado: POLICASTRO LUIS (06-05 Médico).pdf -> Form722- MED.pdf
# Renombrado: POLICASTRO LUIS (MEDICO) (2).pdf -> Form723- MED.pdf
# Renombrado: POLICASTRO LUIS (MEDICO) (3).pdf -> Form724- MED.pdf
# Renombrado: Presentismo medico.pdf -> Form725- MED.pdf
# Renombrado: Presentismo médico.pdf -> Form726- MED.pdf
# Renombrado: Reyres De Riera (Medico) (2).pdf -> Form727- MED.pdf
# Renombrado: Reyres de Riera (Medico).pdf -> Form728- MED.pdf
# Renombrado: Reyres de Riera (Médico).pdf -> Form729- MED.pdf
# Renombrado: Reyres De Riera Magdalena (Medico).pdf -> Form730- MED.pdf
# Renombrado: REYRES MAGDALENA (8 Médico).pdf -> Form731- MED.pdf
# Renombrado: Rios Carmen (Medico).pdf -> Form732- MED.pdf
# Renombrado: RODRIGUEZ MARTA (06-05 Médico).pdf -> Form733- MED.pdf
# Renombrado: ROLDAN JUAN (04-05 Médico).pdf -> Form734- MED.pdf
# Renombrado: SCHICAPPASE OLGA (05-05 Médico).pdf -> Form735- MED.pdf
# Renombrado: SID ROBERTO (03-05 Médico).pdf -> Form736- MED.pdf
# Renombrado: MEDICO (KOREN) (36).pdf -> Form1841- MED.pdf
# Renombrado: MEDICO (KOREN) (37).pdf -> Form1842- MED.pdf
# Renombrado: MEDICO (KOREN) (39).pdf -> Form1843- MED.pdf
# Renombrado: MEDICO (KOREN) (42).pdf -> Form1844- MED.pdf
# Renombrado: MEDICO (KOREN) (6).pdf -> Form1845- MED.pdf
# Renombrado: MEDICO (KOREN) (62).pdf -> Form1846- MED.pdf
# Renombrado: MEDICO (KOREN) (63).pdf -> Form1847- MED.pdf
# Renombrado: MEDICO (LEZCANO) (12).pdf -> Form1848- MED.pdf
# Renombrado: MEDICO (LEZCANO) (3).pdf -> Form1849- MED.pdf
# Renombrado: MEDICO (LEZCANO) (4).pdf -> Form1850- MED.pdf
# Renombrado: MEDICO (LEZCANO).pdf -> Form1851- MED.pdf
# Renombrado: MEDICO (Maiocchi) (2).pdf -> Form1852- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (101).pdf -> Form1853- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (12).pdf -> Form1854- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (14).pdf -> Form1855- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (162).pdf -> Form1856- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (165).pdf -> Form1857- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (166).pdf -> Form1858- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (167).pdf -> Form1859- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (169).pdf -> Form1860- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (17).pdf -> Form1861- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (170).pdf -> Form1862- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (171).pdf -> Form1863- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (172).pdf -> Form1864- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (176).pdf -> Form1865- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (18).pdf -> Form1866- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (19).pdf -> Form1867- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (20).pdf -> Form1868- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (21).pdf -> Form1869- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (24).pdf -> Form1870- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (25).pdf -> Form1871- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (26).pdf -> Form1872- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (29).pdf -> Form1873- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (30).pdf -> Form1874- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (31).pdf -> Form1875- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (33).pdf -> Form1876- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (34).pdf -> Form1877- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (37).pdf -> Form1878- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (38).pdf -> Form1879- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (39).pdf -> Form1880- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (40).pdf -> Form1881- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (43).pdf -> Form1882- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (44).pdf -> Form1883- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (45).pdf -> Form1884- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (47).pdf -> Form1885- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (51).pdf -> Form1886- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (52).pdf -> Form1887- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (54).pdf -> Form1888- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (55).pdf -> Form1889- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (56).pdf -> Form1890- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (57).pdf -> Form1891- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (58).pdf -> Form1892- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (62).pdf -> Form1893- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (63).pdf -> Form1894- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (65).pdf -> Form1895- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (67).pdf -> Form1896- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (68).pdf -> Form1897- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (75).pdf -> Form1898- MED.pdf
# Renombrado: MEDICO (MARQUEZ) (8).pdf -> Form1899- MED.pdf
# Renombrado: MEDICO (MORALES) (13).pdf -> Form1900- MED.pdf
# Renombrado: MEDICO (MORALES) (3).pdf -> Form1901- MED.pdf
# Renombrado: MEDICO (MORALES) (7).pdf -> Form1902- MED.pdf
# Renombrado: MEDICO - MALDONADO, Maria.pdf -> Form1903- MED.pdf
# Renombrado: MEDICO - MENDEZ MARIN, Martina (2).pdf -> Form1904- MED.pdf
# Renombrado: MEDICO - MENDEZ MARIN, Martina.pdf -> Form1905- MED.pdf
# Renombrado: MEDICO - PERALTA, Santino (2).pdf -> Form1906- MED.pdf
# Renombrado: MEDICO 3,10,17 y 24-6.pdf -> Form1907- MED.pdf
# Renombrado: Medico Beas Olga.pdf -> Form1908- MED.pdf
# Renombrado: MEDICO COBOS.pdf -> Form1909- MED.pdf
# Renombrado: Medico Giacoio Nilda.pdf -> Form1910- MED.pdf
# Renombrado: MEDICO KOREN (12).pdf -> Form1911- MED.pdf
# Renombrado: MEDICO KOREN (13).pdf -> Form1912- MED.pdf
# Renombrado: MEDICO KOREN (14).pdf -> Form1913- MED.pdf
# Renombrado: MEDICO KOREN (15).pdf -> Form1914- MED.pdf
# Renombrado: MEDICO KOREN (16).pdf -> Form1915- MED.pdf
# Renombrado: MEDICO KOREN (17).pdf -> Form1916- MED.pdf
# Renombrado: MEDICO KOREN (19).pdf -> Form1917- MED.pdf
# Renombrado: MEDICO KOREN (20).pdf -> Form1918- MED.pdf
# Renombrado: MEDICO KOREN (22).pdf -> Form1919- MED.pdf
# Renombrado: MEDICO KOREN (28).pdf -> Form1920- MED.pdf
# Renombrado: MEDICO KOREN (5).pdf -> Form1921- MED.pdf
# Renombrado: MEDICO KOREN (6).pdf -> Form1922- MED.pdf
# Renombrado: MEDICO KOREN (7).pdf -> Form1923- MED.pdf
# Renombrado: MEDICO KOREN (8).pdf -> Form1924- MED.pdf
# Renombrado: MEDICO KOREN (9).pdf -> Form1925- MED.pdf
# Renombrado: Medico Nelida Amigo.pdf -> Form1926- MED.pdf
# Renombrado: MEDICO NUÑEZ DIONISIO.pdf -> Form1927- MED.pdf
# Renombrado: MEDICO PASO JULIO.pdf -> Form1928- MED.pdf
# Renombrado: MEDICO PEDROZO CARLOS (2).pdf -> Form1929- MED.pdf
# Renombrado: MEDICO RAMIREZ).pdf -> Form1930- MED.pdf
# Renombrado: Medico Sardjian rosa.pdf -> Form1931- MED.pdf
# Renombrado: Medico Toro Haydee.pdf -> Form1932- MED.pdf
# Renombrado: PENA GERMAN (MEDICO) (2).pdf -> Form1933- MED.pdf
# Renombrado: PENA GERMAN (MEDICO).pdf -> Form1934- MED.pdf
# Renombrado: PITELLI ANGELA (MEDICO).pdf -> Form1935- MED.pdf
# Renombrado: RANDAZZO ANGEL (MEDICO).pdf -> Form1936- MED.pdf
# Renombrado: RANDAZZO ANGEL (Médico) (2).pdf -> Form1937- MED.pdf
# Renombrado: RANDAZZO ANGEL (Médico).pdf -> Form1938- MED.pdf
# Renombrado: Rivas Alejandro (Medico) (2).pdf -> Form1939- MED.pdf
# Renombrado: Rivas Alejandro (Medico).pdf -> Form1940- MED.pdf
# Renombrado: Rivas Alejandro (Médico) (2).pdf -> Form1941- MED.pdf
# Renombrado: Rivas Alejandro (Médico).pdf -> Form1942- MED.pdf
# Renombrado: ROCCA AMALIA (MEDICO).pdf -> Form1943- MED.pdf
# Renombrado: Rodriguez Osvaldo (Médico) (2).pdf -> Form1944- MED.pdf
# Renombrado: Rodriguez Osvaldo (Médico).pdf -> Form1945- MED.pdf
# Renombrado: ROTUNDO ROQUE (MEDICO).pdf -> Form1946- MED.pdf
# Renombrado: RUIZ ALBERTO (MEDICO).pdf -> Form1947- MED.pdf
# Renombrado: Sabatini Fernanda (MEDICO) (2).pdf -> Form1948- MED.pdf
# Renombrado: Sabatini Fernanda (Medico) (3).pdf -> Form1949- MED.pdf
# Renombrado: Sabatini Fernanda (Medico) (4).pdf -> Form1950- MED.pdf
# Renombrado: SABATINI FERNANDA (MEDICO).pdf -> Form1951- MED.pdf
# Renombrado: Sabatini Fernanda (Médico).pdf -> Form1952- MED.pdf
# Renombrado: SOLER JUAN CARLOS (MEDICO).pdf -> Form1953- MED.pdf
# Renombrado: Suarez Alberto (Medico) (3).pdf -> Form1954- MED.pdf
# Renombrado: SUAREZ ALBERTO (MEDICO).pdf -> Form1955- MED.pdf
# Renombrado: Suarez Alberto (Médico) (2).pdf -> Form1956- MED.pdf
# Renombrado: Suarez Alberto (Médico).pdf -> Form1957- MED.pdf
# Renombrado: SUELDO FRANCISCA (MEDICO).pdf -> Form1958- MED.pdf
# Renombrado: TADEI (MEDICO).pdf -> Form1959- MED.pdf
# Renombrado: TISCORNIA MARIA (MEDICO) (2).pdf -> Form1960- MED.pdf
# Renombrado: TISCORNIA MARIA (MEDICO).pdf -> Form1961- MED.pdf
# Renombrado: Villalba Edith (MEDICO) (2).pdf -> Form1962- MED.pdf
# Renombrado: Villalba Edith (Medico).pdf -> Form1963- MED.pdf
# Renombrado: VISITAS MEDICAS (2).pdf -> Form1964- MED.pdf
# Renombrado: VISITAS MEDICAS PALIATIVOS.pdf -> Form1965- MED.pdf
# Renombrado: Visitas médicas (10).pdf -> Form1966- MED.pdf
# Renombrado: Visitas médicas (102).pdf -> Form1967- MED.pdf
# Renombrado: Visitas médicas (104).pdf -> Form1968- MED.pdf
# Renombrado: Visitas médicas (105).pdf -> Form1969- MED.pdf
# Renombrado: Visitas médicas (107).pdf -> Form1970- MED.pdf
# Renombrado: Visitas médicas (108).pdf -> Form1971- MED.pdf
# Renombrado: Visitas médicas (11).pdf -> Form1972- MED.pdf
# Renombrado: Visitas médicas (113).pdf -> Form1973- MED.pdf
# Renombrado: Visitas médicas (115).pdf -> Form1974- MED.pdf
# Renombrado: Visitas médicas (116).pdf -> Form1975- MED.pdf
# Renombrado: Visitas médicas (118).pdf -> Form1976- MED.pdf
# Renombrado: Visitas médicas (119).pdf -> Form1977- MED.pdf
# Renombrado: Visitas médicas (12).pdf -> Form1978- MED.pdf
# Renombrado: Visitas médicas (120).pdf -> Form1979- MED.pdf
# Renombrado: Visitas médicas (122).pdf -> Form1980- MED.pdf
# Renombrado: Visitas médicas (123).pdf -> Form1981- MED.pdf
# Renombrado: Visitas médicas (126).pdf -> Form1982- MED.pdf
# Renombrado: Visitas médicas (127).pdf -> Form1983- MED.pdf
# Renombrado: Visitas médicas (130).pdf -> Form1984- MED.pdf
# Renombrado: Visitas médicas (131).pdf -> Form1985- MED.pdf
# Renombrado: Visitas médicas (134).pdf -> Form1986- MED.pdf
# Renombrado: Visitas médicas (138).pdf -> Form1987- MED.pdf
# Renombrado: Visitas médicas (142).pdf -> Form1988- MED.pdf
# Renombrado: Visitas médicas (143).pdf -> Form1989- MED.pdf
# Renombrado: Visitas médicas (148).pdf -> Form1990- MED.pdf
# Renombrado: Visitas médicas (151).pdf -> Form1991- MED.pdf
# Renombrado: Visitas médicas (153).pdf -> Form1992- MED.pdf
# Renombrado: Visitas médicas (157).pdf -> Form1993- MED.pdf
# Renombrado: Visitas médicas (158).pdf -> Form1994- MED.pdf
# Renombrado: Visitas médicas (159).pdf -> Form1995- MED.pdf
# Renombrado: Visitas médicas (160).pdf -> Form1996- MED.pdf
# Renombrado: Visitas médicas (162).pdf -> Form1997- MED.pdf
# Renombrado: Visitas médicas (164).pdf -> Form1998- MED.pdf
# Renombrado: Visitas médicas (166).pdf -> Form1999- MED.pdf
# Renombrado: Visitas médicas (170).pdf -> Form2000- MED.pdf
# Renombrado: Visitas médicas (171).pdf -> Form2001- MED.pdf
# Renombrado: Visitas médicas (172).pdf -> Form2002- MED.pdf
# Renombrado: Visitas médicas (175).pdf -> Form2003- MED.pdf
# Renombrado: Visitas médicas (176).pdf -> Form2004- MED.pdf
# Renombrado: Visitas médicas (177).pdf -> Form2005- MED.pdf
# Renombrado: Visitas médicas (18).pdf -> Form2006- MED.pdf
# Renombrado: Visitas médicas (183).pdf -> Form2007- MED.pdf
# Renombrado: Visitas médicas (184).pdf -> Form2008- MED.pdf
# Renombrado: Visitas médicas (186).pdf -> Form2009- MED.pdf
# Renombrado: Visitas médicas (189).pdf -> Form2010- MED.pdf
# Renombrado: Visitas médicas (193).pdf -> Form2011- MED.pdf
# Renombrado: Visitas médicas (195).pdf -> Form2012- MED.pdf
# Renombrado: Visitas médicas (197).pdf -> Form2013- MED.pdf
# Renombrado: Visitas médicas (198).pdf -> Form2014- MED.pdf
# Renombrado: Visitas médicas (235).pdf -> Form2015- MED.pdf
# Renombrado: Visitas médicas (241).pdf -> Form2016- MED.pdf
# Renombrado: Visitas médicas (246).pdf -> Form2017- MED.pdf
# Renombrado: Visitas médicas (247).pdf -> Form2018- MED.pdf
# Renombrado: Visitas médicas (249).pdf -> Form2019- MED.pdf
# Renombrado: Visitas médicas (252).pdf -> Form2020- MED.pdf
# Renombrado: Visitas médicas (256).pdf -> Form2021- MED.pdf
# Renombrado: Visitas médicas (257).pdf -> Form2022- MED.pdf
# Renombrado: Visitas médicas (262).pdf -> Form2023- MED.pdf
# Renombrado: Visitas médicas (263).pdf -> Form2024- MED.pdf
# Renombrado: Visitas médicas (265).pdf -> Form2025- MED.pdf
# Renombrado: Visitas médicas (269).pdf -> Form2026- MED.pdf
# Renombrado: Visitas médicas (271).pdf -> Form2027- MED.pdf
# Renombrado: Visitas médicas (274).pdf -> Form2028- MED.pdf
# Renombrado: Visitas médicas (276).pdf -> Form2029- MED.pdf
# Renombrado: Visitas médicas (280).pdf -> Form2030- MED.pdf
# Renombrado: Visitas médicas (285).pdf -> Form2031- MED.pdf
# Renombrado: Visitas médicas (287).pdf -> Form2032- MED.pdf
# Renombrado: Visitas médicas (289).pdf -> Form2033- MED.pdf
# Renombrado: Visitas médicas (291).pdf -> Form2034- MED.pdf
# Renombrado: Visitas médicas (293).pdf -> Form2035- MED.pdf
# Renombrado: Visitas médicas (299).pdf -> Form2036- MED.pdf
# Renombrado: Visitas médicas (3).pdf -> Form2037- MED.pdf
# Renombrado: Visitas médicas (303).pdf -> Form2038- MED.pdf
# Renombrado: Visitas médicas (304).pdf -> Form2039- MED.pdf
# Renombrado: Visitas médicas (305).pdf -> Form2040- MED.pdf
# Renombrado: Visitas médicas (306).pdf -> Form2041- MED.pdf
# Renombrado: Visitas médicas (307).pdf -> Form2042- MED.pdf
# Renombrado: Visitas médicas (308).pdf -> Form2043- MED.pdf
# Renombrado: Visitas médicas (310).pdf -> Form2044- MED.pdf
# Renombrado: Visitas médicas (311).pdf -> Form2045- MED.pdf
# Renombrado: Visitas médicas (313).pdf -> Form2046- MED.pdf
# Renombrado: Visitas médicas (314).pdf -> Form2047- MED.pdf
# Renombrado: Visitas médicas (316).pdf -> Form2048- MED.pdf
# Renombrado: Visitas médicas (319).pdf -> Form2049- MED.pdf
# Renombrado: Visitas médicas (320).pdf -> Form2050- MED.pdf
# Renombrado: Visitas médicas (321).pdf -> Form2051- MED.pdf
# Renombrado: Visitas médicas (322).pdf -> Form2052- MED.pdf
# Renombrado: Visitas médicas (329).pdf -> Form2053- MED.pdf
# Renombrado: Visitas médicas (330).pdf -> Form2054- MED.pdf
# Renombrado: Visitas médicas (333).pdf -> Form2055- MED.pdf
# Renombrado: Visitas médicas (334).pdf -> Form2056- MED.pdf
# Renombrado: Visitas médicas (337).pdf -> Form2057- MED.pdf
# Renombrado: Visitas médicas (341).pdf -> Form2058- MED.pdf
# Renombrado: Visitas médicas (342).pdf -> Form2059- MED.pdf
# Renombrado: Visitas médicas (344).pdf -> Form2060- MED.pdf
# Renombrado: Visitas médicas (347).pdf -> Form2061- MED.pdf
# Renombrado: Visitas médicas (43).pdf -> Form2062- MED.pdf
# Renombrado: Visitas médicas (45).pdf -> Form2063- MED.pdf
# Renombrado: Visitas médicas (46).pdf -> Form2064- MED.pdf
# Renombrado: Visitas médicas (47).pdf -> Form2065- MED.pdf
# Renombrado: Visitas médicas (49).pdf -> Form2066- MED.pdf
# Renombrado: Visitas médicas (50).pdf -> Form2067- MED.pdf
# Renombrado: Visitas médicas (51).pdf -> Form2068- MED.pdf
# Renombrado: Visitas médicas (52).pdf -> Form2069- MED.pdf
# Renombrado: Visitas médicas (53).pdf -> Form2070- MED.pdf
# Renombrado: Visitas médicas (54).pdf -> Form2071- MED.pdf
# Renombrado: Visitas médicas (57).pdf -> Form2072- MED.pdf
# Renombrado: Visitas médicas (59).pdf -> Form2073- MED.pdf
# Renombrado: Visitas médicas (6).pdf -> Form2074- MED.pdf
# Renombrado: Visitas médicas (60).pdf -> Form2075- MED.pdf
# Renombrado: Visitas médicas (62).pdf -> Form2076- MED.pdf
# Renombrado: Visitas médicas (63).pdf -> Form2077- MED.pdf
# Renombrado: Visitas médicas (67).pdf -> Form2078- MED.pdf
# Renombrado: Visitas médicas (69).pdf -> Form2079- MED.pdf
# Renombrado: Visitas médicas (70).pdf -> Form2080- MED.pdf
# Renombrado: Visitas médicas (72).pdf -> Form2081- MED.pdf
# Renombrado: Visitas médicas (78).pdf -> Form2082- MED.pdf
# Renombrado: Visitas médicas (80).pdf -> Form2083- MED.pdf
# Renombrado: Visitas médicas (82).pdf -> Form2084- MED.pdf
# Renombrado: Visitas médicas (83).pdf -> Form2085- MED.pdf
# Renombrado: Visitas médicas (84).pdf -> Form2086- MED.pdf
# Renombrado: Visitas médicas (86).pdf -> Form2087- MED.pdf
# Renombrado: Visitas médicas (93).pdf -> Form2088- MED.pdf
# Renombrado: Visitas médicas (96).pdf -> Form2089- MED.pdf
# Renombrado: Visitas médicas (97).pdf -> Form2090- MED.pdf
# Renombrado: Visitas médicas (98).pdf -> Form2091- MED.pdf
# Renombrado: Zarembo Hector (Médico).pdf -> Form2092- MED.pdf

# %% [markdown]
# ## informe_v2.0
#
#  This report provides detailed information about the division of files within each folder, including the total number of PDFs and the distribution of PDFs based on the number of pages they contain. It also specifies the date and version of the report.

# %%
import os

# Path of the main folder where files and subfolders are located
ruta_principal = 'C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion'
ruta_destino = ruta_principal + '1-Form to Train'
# Check if the main folder exists
if os.path.exists(ruta_principal):
    # Traverse the main folder and all its subfolders
    for directorio_actual, subdirectorios, archivos in os.walk(ruta_principal):
        for archivo in archivos:
            if archivo.lower().endswith('.pdf'):
                # Full path of source and destination
                origen = os.path.join(directorio_actual, archivo)
                destino = os.path.join(ruta_destino, archivo)
                # Copy the file
                shutil.copy(origen, destino)
                
else:
    print(f"The main folder {ruta_principal} does not exist.")

# %% [markdown]
# Based on the results of the informe_v2.0, we proceed with the creation of 3 datasets to train the machine learning model.
#
#     - Training Dataset
#
#     - Excluded Data
#
#     - Test Dataset

# %%
# In this stage, we perform an initial selection of files 

import os
import shutil
from tqdm import tqdm  # Import tqdm for progress bar

# Path to the main folder where files and subfolders are located
ruta_principal = 'C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion'
ruta_destino = 'C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/1-Forms to Train'

# Folder to be omitted
carpeta_omitir = 'Test Dataset'

# Check if the main folder and the destination folder exist
if os.path.exists(ruta_principal):
    if not os.path.exists(ruta_destino):
        os.makedirs(ruta_destino)  # Create the destination folder if it doesn't exist

    # List of PDF files in the main folder
    archivos_pdf = [os.path.join(directorio_actual, archivo) for directorio_actual, _, archivos in os.walk(ruta_principal) for archivo in archivos if archivo.lower().endswith('.pdf')]

    # Total number of PDF files
    total_archivos_pdf = len(archivos_pdf)

    # Iterate through the PDF files and copy them using tqdm, omitting the specified folder
    for archivo in tqdm(archivos_pdf, unit='archivo', unit_scale=True, desc='Copying files'):
        nombre_archivo = os.path.basename(archivo)
        destino = os.path.join(ruta_destino, nombre_archivo)

        # Check if the current directory is equal to the folder to be omitted
        if not carpeta_omitir in archivo:
            # Copy the file
            shutil.copy2(archivo, destino)

    print("PDF files successfully copied to '1-Forms to Train'.")
else:
    print(f"The main folder {ruta_principal} does not exist.")
# Out:
# Copiando archivos: 100%|██████████| 11.4k/11.4k [07:29<00:00, 25.3archivo/s]
# Archivos PDF copiados a '1-Form to Train' con éxito.

# %% [markdown]
#  Moving files that will not be used to another folder for better dataset control.

# %%
import os
import random
from shutil import move
from tqdm import tqdm

# Paths of the source and destination folders
source_folder = 'C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/1-Forms to Train'
test_destination_folder = 'C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/3-Forms to Test'
validation_destination_folder = 'C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion/2-Validation set'

# Number of files to send to each destination
test_files_count = 806
validation_files_count = 2351

# List of files in the source folder
files_in_source = os.listdir(source_folder)

# Random selection of files for the Test folder
files_for_test = random.sample(files_in_source, test_files_count)

# Random selection of files for the Validation folder
files_for_validation = random.sample(files_in_source, validation_files_count)

# Move files to the Test folder
print("Sending files to the '3-Forms to Test' folder...")
for file in tqdm(files_for_test, total=test_files_count):
    source = os.path.join(source_folder, file)
    destination = os.path.join(test_destination_folder, file)
    move(source, destination)

# Move files to the Validation folder
print("Sending files to the '2-Validation set' folder...")
for file in tqdm(files_for_validation, total=validation_files_count):
    source = os.path.join(source_folder, file)
    destination = os.path.join(validation_destination_folder, file)
    move(source, destination)

print("Files sent successfully.")
# Out:
# Enviando archivos a la carpeta 3-Forms to Test...
#   7%|▋         | 53/806 [00:00<00:01, 526.33it/s]
# 100%|██████████| 806/806 [00:03<00:00, 220.94it/s]
# Archivos enviados con éxito.

# %% [markdown]
# ## 5- Compliance with GCP Minimum Requirements
#
# This repository ensures compliance with the minimum requirements set by Google Cloud Platform (GCP) through the following measures:
#
#    - PDF Composition Report: A comprehensive report detailing the composition of PDF files within each folder is generated to maintain transparency and facilitate understanding of the dataset.
#
#    - Data Selection: A careful selection process is implemented to extract data up to 1GB specifically tailored for model training purposes, ensuring efficiency and optimal resource utilization.
#
#    - Text Verification: Document verification is conducted to ensure that all included files meet the minimum text requirements, specifically containing 8-point text at 150 DPI, thereby ensuring data quality and consistency.

# %% [markdown]
# ## informe_v3.0
#
# After moving the files that will not be used for training, the following script generates a report detailing the composition of PDF files in each folder within the specified location.
#
# It calculates the total number of PDFs, their percentage relative to all files, and provides a breakdown of PDFs in each subfolder.
#
# Finally, it saves the report to a text file.

# %%
import os
import datetime

# Defining the location where the folders containing PDF files are stored
location = 'C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion'

# Setting the version of the report
report_version = '3.0'

# Function to generate a report for a specific folder
def get_folder_report(folder):
    # Getting the full path of the folder
    full_folder_path = os.path.join(location, folder)
    
    # Counting the total number of files in the folder
    total_files = 0
    for _, _, files in os.walk(full_folder_path):
        total_files += len(files)
    
    # Getting the current date
    current_date = datetime.date.today()
    
    # Constructing the report header with date and version
    report = f"Date: {current_date}\n"
    report += f"Version: {report_version}\n\n"
    report += f"Folder: {folder}\n"
    
    # Counting the total number of files in all folders
    sum_total_files = 0
    for _, _, files in os.walk(location):
        sum_total_files += len(files)
        
    # Calculating the percentage of files in the current folder compared to all files
    total_percentage = (total_files / sum_total_files) * 100
    
    # Adding total number of files and percentage to the report
    report += f"Total PDFs: {total_files} - {total_percentage:.2f}%\n"
    
    # Iterating through subfolders and adding their details to the report
    for subfolder in os.listdir(full_folder_path):
        full_subfolder_path = os.path.join(full_folder_path, subfolder)
        if os.path.isdir(full_subfolder_path):
            subfolder_files = len(os.listdir(full_subfolder_path))
            percentage = (subfolder_files / sum_total_files) * 100
            select_new_data = (percentage * subfolder_files) / 100
            report += f"  -{subfolder}: {subfolder_files} PDFs - {percentage:.2f}% - {select_new_data:.2f} files to select\n"
    
    return report

# Generating a report for each folder in the location
general_report = ""
for folder in os.listdir(location):
    if os.path.isdir(os.path.join(location, folder)):
        general_report += get_folder_report(folder)

# Saving the report to a text file
file_name = f'report_v{report_version}.txt'
with open(file_name, 'w') as file:
    file.write(general_report)

# Printing a success message
print(f"Report generated successfully in '{file_name}'.")
# Out:
# Informe generado con éxito en 'informe_v3.0.txt'.

# %% [markdown]
# ## Data Filtering for Azure Minimum Requirements
#
# To meet the minimum requirements of Azure, a data filtering process is performed.
#
# Based on the report detailing the composition of PDF files in each folder, a filtering of the files is carried out, utilizing xx criteria to reduce the final dataset that will be used to train the model:
#
# - Visual Characteristics: According to the method by which the file was digitized.
#
# - File Size: According to the amount of disk space it occupies.
#
# Final Conclusion: There is an apparent relationship between the file size, image quality, and the digitization method of the form. Based on this observation, files that will not be used for model training are separated.

# %% [markdown]
# ## informe_v4.0
#
# After all the modifications and studies carried out on the files, a final report is prepared that shows how the files that will serve as training data are composed and distributed. The ETF process continues, with another layer that will be developed in another stage.

# %%
import os
import datetime

# Directory where the files and subfolders are located
location = 'C:/Users/HP/My Drive/Inteligencia Artificial/PROJECTS/House24 - Toto/House24 Facturacion'

# Report version
report_version = '4.0'

# Function to generate folder report
def get_folder_report(folder):
    full_folder_path = os.path.join(location, folder)
    
    # Count total number of files in the folder
    total_files = 0
    for _, _, files in os.walk(full_folder_path):
        total_files += len(files)
    
    # Get current date
    current_date = datetime.date.today()
    
    # Initialize report string
    report = f"Fecha: {current_date}\n"
    report += f"Version: {report_version}\n\n"
    report += f"Carpeta: {folder}\n"
    
    # Calculate total size of files in the folder
    total_size = 0
    for dirpath, dirnames, filenames in os.walk(full_folder_path):
        for filename in filenames:
            file_path = os.path.join(dirpath, filename)
            total_size += os.path.getsize(file_path)
    
    # Convert total size to MB
    total_size = total_size / (1024 * 1024)
    
    # Calculate percentage of total files
    total_files_percentage = (total_files / sum_total_files) * 100   
    
    # Add total files information to the report
    report += f"Total PDFs: {total_files} - {total_size:.2f}MB - {total_files_percentage:.2f}%\n"
    
    # Loop through subfolders
    for subfolder in os.listdir(full_folder_path):
        subfolder_path = os.path.join(full_folder_path, subfolder)
        if os.path.isdir(subfolder_path):
            # Count total number of files in each subfolder
            files_in_subfolder = len(os.listdir(subfolder_path))
            report += f"  -{subfolder}: {files_in_subfolder} PDFs\n"
    
    return report

# Generate the overall report
general_report = ""
for folder in os.listdir(location):
    if os.path.isdir(os.path.join(location, folder)):
        general_report += get_folder_report(folder)

# Save the report to a text file
file_name = f'report_v{report_version}.txt'
with open(file_name, 'w') as file:
    file.write(general_report)

print(f"Report generated successfully in '{file_name}'.")
# Out:
# Informe generado con éxito en 'informe_v4.0.txt'.
